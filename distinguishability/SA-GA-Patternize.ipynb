# %% [markdown]
# # Prerequisites
# First, we have to setup the pretrained AI model from ViSiL.
# We also import any required libraries.

# %%
from model.visil import ViSiL
from datasets import load_video

# %%
# # Let's try loading the 2 example videos and calculating the score
model = ViSiL('ckpt/resnet/')
v1 = load_video('examples/video1.gif')
v2 = load_video('examples/video2.gif')
v1features = model.extract_features(v1, batch_sz=32)
v2features = model.extract_features(v2, batch_sz=32)
similarity = model.calculate_video_similarity(v1features, v2features)
similarity
# Out:
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/layers.py:9: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/layers.py:10: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/visil.py:47: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/nets/vgg_preprocessing.py:249: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/nets/vgg_preprocessing.py:256: The name tf.rint is deprecated. Please use tf.math.rint instead.
#
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/nets/vgg_preprocessing.py:256: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/nets/vgg_preprocessing.py:279: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/nets/resnet_utils.py:230: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/djb/miniconda3/envs/visil/lib/python3.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/visil.py:105: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# [INFO] Queries will NOT be loaded to the gpu
# WARNING:tensorflow:From /home/djb/miniconda3/envs/visil/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/visil.py:144: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# [INFO] 274 layers loaded
# INFO:tensorflow:Initialize variable attention_layer/context_vector:0 from checkpoint ckpt/resnet/ with attention_layer/context_vector
# INFO:tensorflow:Initialize variable resnet_v1_50/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/weights:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/weights
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/gamma:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/gamma
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/beta:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/beta
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance:0 from checkpoint ckpt/resnet/ with resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/BatchNorm/moving_variance
# INFO:tensorflow:Initialize variable video_comparator/conv2d/kernel:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d/kernel
# INFO:tensorflow:Initialize variable video_comparator/conv2d/bias:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d/bias
# INFO:tensorflow:Initialize variable video_comparator/conv2d_1/kernel:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d_1/kernel
# INFO:tensorflow:Initialize variable video_comparator/conv2d_1/bias:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d_1/bias
# INFO:tensorflow:Initialize variable video_comparator/conv2d_2/kernel:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d_2/kernel
# INFO:tensorflow:Initialize variable video_comparator/conv2d_2/bias:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d_2/bias
# INFO:tensorflow:Initialize variable video_comparator/conv2d_3/kernel:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d_3/kernel
# INFO:tensorflow:Initialize variable video_comparator/conv2d_3/bias:0 from checkpoint ckpt/resnet/ with video_comparator/conv2d_3/bias
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/visil.py:148: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/visil.py:74: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/djb/HART/forks/visil/model/visil.py:76: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# 2022-02-21 12:44:32.633049: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2022-02-21 12:44:32.639934: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2592005000 Hz
# 2022-02-21 12:44:32.641238: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55767e2dfa70 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-02-21 12:44:32.641301: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-02-21 12:44:32.654353: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-02-21 12:44:32.896373: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-02-21 12:44:32.896686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Quadro P2000 major: 6 minor: 1 memoryClockRate(GHz): 1.607
# pciBusID: 0000:01:00.0
# 2022-02-21 12:44:32.897078: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-02-21 12:44:32.900258: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-02-21 12:44:32.901590: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2022-02-21 12:44:32.901868: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2022-02-21 12:44:32.903322: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2022-02-21 12:44:32.904601: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2022-02-21 12:44:32.907783: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-02-21 12:44:32.909138: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-02-21 12:44:32.911486: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-02-21 12:44:32.912106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2022-02-21 12:44:32.912332: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2022-02-21 12:44:33.200685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-02-21 12:44:33.200747: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2022-02-21 12:44:33.200758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2022-02-21 12:44:33.239152: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-02-21 12:44:33.239700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1387] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2022-02-21 12:44:33.240788: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-02-21 12:44:33.243575: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:969] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-02-21 12:44:33.244118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3077 MB memory) -> physical GPU (device: 0, name: Quadro P2000, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2022-02-21 12:44:33.247161: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x557680a789c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-02-21 12:44:33.247245: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro P2000, Compute Capability 6.1
# 2022-02-21 12:44:36.625315: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2022-02-21 12:44:36.844607: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-02-21 12:44:38.342407: W tensorflow/core/common_runtime/bfc_allocator.cc:305] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2022-02-21 12:44:39.235951: W tensorflow/core/common_runtime/bfc_allocator.cc:305] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 0.6435802

# %% [markdown]
# ## Pattern distinguishability maximalization
# We have 44 phonemes that require a pattern. These patterns need to be distinguishable from eachother, to the highest degree possible.
# Below is a model which can compare two patterns, pairwise only. At the bottom an overview of the methods of pattern collection is given.
#
# ## Pairwise Model
# https://github.com/MKLab-ITI/visil provides a pretrained model for video distinguishability (referred to as ViSiL).
# We shall use this model as a baseline for pairwise pattern distinguishability.
#
# ## Complete Patterns Model
# The above model gives us the possibility to calculate the total score of a pair, but does not provide a method for quickly calculating the score of a collection of patterns.
# There is of course the brute force method, generating a new set of patterns and getting the score for them, improving over time, but this is not practical due to runtime.
# Then there are two known methods of decreasing runtime for calculating the score of a collection of patterns.
# ### Simulated Annealing (SA)
# Simulated Annealing is a method where the score of a collection of patterns is improved by starting with a random collection of patterns, and then iteratively changing the collection of patterns by (sub)randomly changing one of the patterns.
#
# ### Genetic Algorithm (GA)
# Genetic Algorithm is a method where the score of a collection of patterns is improved by combining two pattern collections by swapping half the patterns in each with the other.
# Afterwards, continue with both collections using Simulated Annealing.
#
# ## Step by step plan
# This plan works on a thread-by-thread basis, and can be multithreaded to speed up the process. Files with scores are ouput at the end without interaction between threads hence it is threadsafe.
# 1. Generate two sets of patterns.
# 2. Take the first of the two sets.
# 3. Calculate and store the score of each pair of patterns using ViSiL. The score should be stored in a hash (or similar) to be used later.
# 4. Calculate the score of the set. This is done by taking the median score of the pairs in the set.
# 5. Swap out a pair using SA.
# 6. Recalculate the score of the set and decide what action to undertake next using SA. See the algorithm code below.
# 7. First set? Go to 7.1. Second set? Go to 7.2.
#    1. Take the second set and go to step 3.
#    2. If the max iterations are not reached, apply GA to the two sets and continue with step 2. Otherwise, apply SA a last time before returning the best score.

# %% [markdown]
# ### Import

# %%
import numpy as np
import random
from collections.abc import Callable, Mapping, Collection
from typing import Tuple

# %% [markdown]
# ### Pattern Class
# Will hold some basic information about a pattern.

# %%
class Pattern:
    def __init__(self, file: str):
        self.file = file
    
    def __str__(self):
        return self.file
    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ### Pair-wise score calculation
# Caches existing scores in hashmap.
# The `__pair_score_function__` is used t calculate the score of a pair of patterns.

# %%
# Modify this method to define your own pattern score calculation
def get_pair_score_function(x: Pattern, y: Pattern):
    query_video = load_video('examples/' + str(x))
    target_video = load_video('examples/' + str(y))
    
    query_features = model.extract_features(query_video, batch_sz=32)
    target_features = model.extract_features(target_video, batch_sz=32)
    return model.calculate_video_similarity(query_features, target_features)

# %%
__score_cache__: Mapping = {} # Do not use this variable elsewhere!
def get_pattern_pair_score(x: Pattern, y: Pattern) -> np.float32:
    if (x, y) in __score_cache__:
        return __score_cache__[(x, y)]
    else:
        score = get_pair_score_function(x, y)
        __score_cache__[(x, y)] = score
        return score

# %% [markdown]
# ### Complete pattern set score calculation.
# Calculates the full set score (using the cached scores). Requires a Callable function to calculate the pattern score (which we suggest to be np.median).

# %%
def get_set_score(element_list: Collection,score_picking: Callable) -> np.float32:
    return 1 - abs(score_picking([get_pattern_pair_score(x, y) for x, y in zip(element_list, element_list[1:])]))

# %% [markdown]
# ### Dynamic Pattern Generation
# Uses a pattern generator to generate new random patterns.

# %%
def get_dynamic_pattern() -> Pattern:
    return Pattern('pattern_' + str(np.random.randint(0, 20)) + '.gif')

# %% [markdown]
# ### Simulated Annealing
# Uses the dynamic pattern generator to generate new patterns.

# %%
def SA(element_set: Collection, score_picking: Callable,
                            temperature: float = 1.0, cooling_rate: float = 0.99, iter: int = 100) -> Tuple[Pattern, np.float32]:

    # Get the current score of the set
    current_score = get_set_score(element_set, score_picking)

    # Run through iterations
    for i in range(iter):

        # Create a copy of the set
        new_element_set = element_set.copy()

        # Replace a pattern in the set with a new one
        new_element_set.remove(random.choice(new_element_set))
        new_element_set.append(get_dynamic_pattern())
        
        # Get the new score of the set
        new_score = get_set_score(new_element_set, score_picking)

        # If the new score is better, keep the new set
        if new_score > current_score:
            element_set = new_element_set
            current_score = new_score

        # Else accept the new set with a probability
        else:
            if np.random.random() < np.exp((new_score - current_score) / temperature):
                element_set = new_element_set
                current_score = new_score

        # Cool the temperature
        temperature *= cooling_rate
        
        # Print an update every 100 cycles
        if i % 100 == 0:
            print("New score {} with set {}".format(new_score, element_set))

    # Return the new pattern set and its score
    return element_set, current_score

# %% [markdown]
# ### Genetic Algorithm
# Combines two equally large sets of patterns into two children of said pattern sets.
#
# The `gene_mixing` variable is the degree to which the two set's children represent the other parent.
# If this is set to 0.5, every gene has a 50% chance to swap between parents.

# %%
def GA(element_set_1: Collection, element_set_2: Collection, gene_mixing: float = 0.5) -> Tuple[Collection, Collection]:
    if len(element_set_1) != len(element_set_2):
        raise IndexError("Cannot apply genetic algorithm on two sets of non-equal size!")
    out1 = []
    out2 = []
    for i in range(len(element_set_1)):
        if random.random() >= gene_mixing:
            out2.append(element_set_1[i])
            out1.append(element_set_2[i])
        else:
            out1.append(element_set_1[i])
            out2.append(element_set_2[i])
    return out1, out2

# %% [markdown]
# ### Best pattern set selection
# Selects the best set of patterns

# %%
def get_set(n: int, score_picking: Callable, total_iter: int = 100, GA_gene_mix: float = 0.5,
                        SA_temperature: float = 1.0, SA_cooling_rate: float = 0.99, SA_iter: int = 10000) -> Tuple[Collection, np.float32]:

    # Get random elements
    element_set_1 = [get_dynamic_pattern() for _ in range(n)]
    element_set_2 = [get_dynamic_pattern() for _ in range(n)]

    # Calculate the score for the full set
    score_1 = get_set_score(element_set_1, score_picking)
    score_2 = get_set_score(element_set_2, score_picking)
    print("Initial Scores: {} | {}".format(score_1, score_2))

    # Best set
    best_elements = element_set_1
    best_score = score_1

    # Run total algorithm total_iter times
    for i in range(total_iter):

        # Run genetic algorithm
        element_set_1, element_set_2 = GA(element_set_1, element_set_2, GA_gene_mix)
        
        # Run simulated annealing
        element_set_1, score_1 = SA(element_set_1, score_picking, SA_temperature, SA_cooling_rate, SA_iter)
        element_set_2, score_2 = SA(element_set_2, score_picking, SA_temperature, SA_cooling_rate, SA_iter)

        print("(Iter {} / {}) New Scores: {} | {}".format(i + 1, total_iter, score_1, score_2))

        if score_1 > score_2:
            if score_1 > best_score:
                best_elements = element_set_1
                best_score = score_1
        else:
            if score_2 > best_score:
                best_elements = element_set_2
                best_score = score_2

    # Return the best element list
    return best_elements, best_score

# %% [markdown]
# ### Get pattern test

# %%
patternset, score = get_set(4, np.median, total_iter=1, SA_iter=10000)

print("Best set score is {}, with set: {}".format(score, patternset))
# Out:
# Initial Scores: 0.8765846639871597 | 0.8913472518324852
